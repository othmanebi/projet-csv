# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("all-datasets.csv", sep=';')
data
# Out:
#                                dataset_id provider_id           x          y  \
# 0    004256a7-96e2-4c1c-aee5-074288446290         OM9    5.449700  43.528300
# 1    01e0f8d4-2859-4c56-afea-072b67a8147b         OEB -122.320073  44.173262
# 2    0213f219-b874-4bef-95d6-7dbdc48b6bcd         ODX   -1.051854  43.708754
# 3    03a3611b-2062-4970-9a7e-a5cda8399578      OPLKR0   19.944980  50.064650
# 4    044b8517-073d-4a18-bbf6-ac4186d78cdc         CFE         NaN        NaN
# ..                                    ...         ...         ...        ...
# 621                                   NaN         NaN         NaN        NaN
# 622                                   NaN         NaN         NaN        NaN
# 623                                   NaN         NaN         NaN        NaN
# 624                                   NaN         NaN         NaN        NaN
# 625                                   NaN         NaN         NaN        NaN
#
# ...
