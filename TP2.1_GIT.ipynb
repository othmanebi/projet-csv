# %% [markdown]
# # $\color{red}{\text{ TP2 GIT}}$

# %% [markdown]
# #### 1/ Créer un dépot sur git inviter son collègue
# #### 2/ Inviter son collègue
# #### 3/ Créer un fochier readme qui contient le détail du projet
# #### 4/ Ecrire un programme Python :
#         - Lecture d'un CSV
#         - Remplavce des espaces par des - dans le nom des colonnes
#         - Retire les lignes incomplètes

# %% [markdown]
#  $\color{blue}{\text{ Voir Question 1 et 2 sur github et le dossier sur le bureau}}$

# %% [markdown]
#  $\color{blue}{\text{ Voir Question 3 sur github dans Readme}}$

# %% [markdown]
#  ### $\color{blue}{\text{ Question 4}}$

# %% [markdown]
#  $\color{black}{\text{ Lecture d'un CSV}}$

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("donnees-hospitalieres-covid-19-dep-france.csv", sep = ';')
df
# Out:
#        Code du Département        Date  Nb actuellement hospitalisés  \
# 0                       40  2020-12-05                            47
# 1                       47  2020-12-05                            41
# 2                       75  2020-12-05                           382
# 3                       76  2020-12-05                           261
# 4                       90  2020-12-05                            69
# ...                    ...         ...                           ...
# 291270                  14  2021-02-08                           101
# 291271                  49  2021-02-08                           282
# 291272                  50  2021-02-08                           100
# 291273                  56  2021-02-08                           172
# 291274                  87  2021-02-08                            86
#
#         Nb actuellement en soins intensifs  Total retour à domicile  \
# 0                                        5                      158
# ...

# %% [markdown]
# #### Remplacer les espaces par des tirets dans le nom des colonnes

# %%
df.columns = df.columns.str.replace(' ', '-')
df
# Out:
#        Code-du-Département        Date  Nb-actuellement-hospitalisés  \
# 0                       40  2020-12-05                            47
# 1                       47  2020-12-05                            41
# 2                       75  2020-12-05                           382
# 3                       76  2020-12-05                           261
# 4                       90  2020-12-05                            69
# ...                    ...         ...                           ...
# 291270                  14  2021-02-08                           101
# 291271                  49  2021-02-08                           282
# 291272                  50  2021-02-08                           100
# 291273                  56  2021-02-08                           172
# 291274                  87  2021-02-08                            86
#
#         Nb-actuellement-en-soins-intensifs  Total-retour-à-domicile  \
# 0                                        5                      158
# ...

# %% [markdown]
# #### Retirer les lignes incompletes

# %%
new_df = df.dropna(axis = 0, how ='any') 
new_df
# Out:
#        Code-du-Département        Date  Nb-actuellement-hospitalisés  \
# 1223                    26  2021-03-20                           214
# 1225                    30  2021-03-20                           201
# 1226                    38  2021-03-20                           606
# 1227                    74  2021-03-20                           240
# 1228                    77  2021-03-20                           597
# ...                    ...         ...                           ...
# 290518                  04  2022-02-04                           131
# 290521                  18  2022-02-04                           137
# 290522                  2B  2022-02-04                            72
# 290524                  38  2022-02-04                           721
# 290526                  39  2022-02-04                           124
#
#         Nb-actuellement-en-soins-intensifs  Total-retour-à-domicile  \
# 1223                                    35                     2283
# ...

# %% [markdown]
# #### autres methodes

# %%
df= df.dropna(how='any')
df
# Out:
#        Code-du-Département        Date  Nb-actuellement-hospitalisés  \
# 1223                    26  2021-03-20                           214
# 1225                    30  2021-03-20                           201
# 1226                    38  2021-03-20                           606
# 1227                    74  2021-03-20                           240
# 1228                    77  2021-03-20                           597
# ...                    ...         ...                           ...
# 290518                  04  2022-02-04                           131
# 290521                  18  2022-02-04                           137
# 290522                  2B  2022-02-04                            72
# 290524                  38  2022-02-04                           721
# 290526                  39  2022-02-04                           124
#
#         Nb-actuellement-en-soins-intensifs  Total-retour-à-domicile  \
# 1223                                    35                     2283
# ...
